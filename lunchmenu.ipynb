# %%
import pandas as pd
df = pd.read_csv('note/menu.csv')

# %%
df.head(2)
# Out:
#   ename                   gmail   github         domain  \
# 0   TOM        tom@diginori.com   ppabam    sunsin.shop
# 1   cho  j01040864205@gmail.com  cho6019  cho6019.store
#
#                        vercel         role 2025-01-07 2025-01-08 2025-01-09  \
# 0   https://sunsin.vercel.app           PM        순대국       비지찌개   냉동김밥,컵라면
# 1  https://cho6019.vercel.app  행동강령 수립 위원회        닭개장         규동    얼큰 순대국밥
#
#   2025-01-10  ... 2025-01-16 2025-01-17 2025-01-20 2025-01-21 2025-01-22  \
# 0       잔치국수  ...     오징어 덮밥        짜장면     집밥 도시락      소고기무국          -
# 1       스파게티  ...        간짜장       스파게티   버섯 비프 카레       스파게티        설렁탕
#
#   2025-01-23 2025-01-24 2025-02-03 2025-02-04 2025-02-05
# 0      오징어덮밥        볶음밥        짜장면          -          -
# 1     치킨마요덮밥      등심돈까스   치즈라면, 김밥          -          -
#
# [2 rows x 23 columns]

# %%
for  c in df.columns[6:]:
    print(c)
# Out:
# 2025-01-07
# 2025-01-08
# 2025-01-09
# 2025-01-10
# 2025-01-13
# 2025-01-14
# 2025-01-15
# 2025-01-16
# 2025-01-17
# 2025-01-20
# 2025-01-21
# 2025-01-22
# 2025-01-23
# 2025-01-24
# 2025-02-03
# 2025-02-04
# 2025-02-05

# %%
fdf=df.iloc[0:,6:-2]

# %%
fdf
# Out:
#      2025-01-07 2025-01-08     2025-01-09 2025-01-10   2025-01-13 2025-01-14  \
# 0           순대국       비지찌개       냉동김밥,컵라면       잔치국수         제육덮밥      소고기무국
# 1           닭개장         규동        얼큰 순대국밥       스파게티           한솥   순대국밥 고기만
# 2  닭개장(특) , 꽈배기        주먹밥        얼큰 순대국밥     불닭로제찜닭           한솥       순대국밥
# 3           닭개장        주먹밥        얼큰 순대국밥     불닭로제찜닭           한솥       뼈해장국
# 4           볶음밥       유부초밥            볶음밥   볶음밥 , 연어         연어덮밥        볶음밥
# 5           닭개장       스키야키  참깨라면 작은컵,삼각김밥     불닭로제찜닭            -          -
# 6           자장면         텐동         얼큰 설렁탕       부대찌개       참치김치찌개         한솥
# 7            덮밥         덮밥            설렁탕       부대찌개           김밥         김밥
# 8           볶음밥         규동          한우 곰탕       부대찌개      꽃게 된장찌개         한솥
# 9      일반 짬뽕 보통   무공 옛날돈가스         얼큰 설렁탕       부대찌개  고기김치찌개,라면세트         한솥
#
#      2025-01-15      2025-01-16 2025-01-17 2025-01-20  2025-01-21  2025-01-22  \
# ...

# %%
for i in range(len(fdf)):
    for j in range(len(fdf.columns)):
        ldt=fdf.columns[j]
        fod=fdf.iat[i,j]
        print(f"({ldt},{fod},{df.iat[i,0]})")
# Out:
# (2025-01-07,순대국,TOM)
# (2025-01-08,비지찌개,TOM)
# (2025-01-09,냉동김밥,컵라면,TOM)
# (2025-01-10,잔치국수,TOM)
# (2025-01-13,제육덮밥,TOM)
# (2025-01-14,소고기무국,TOM)
# (2025-01-15,소고기덮밥,TOM)
# (2025-01-16,오징어 덮밥,TOM)
# (2025-01-17,짜장면,TOM)
# (2025-01-20,집밥 도시락,TOM)
# (2025-01-21,소고기무국,TOM)
# (2025-01-22,-,TOM)
# (2025-01-23,오징어덮밥,TOM)
# (2025-01-24,볶음밥,TOM)
# (2025-02-03,짜장면,TOM)
# (2025-01-07,닭개장,cho)
# (2025-01-08,규동,cho)
# (2025-01-09,얼큰 순대국밥,cho)
# (2025-01-10,스파게티,cho)
# (2025-01-13,한솥,cho)
# (2025-01-14,순대국밥 고기만,cho)
# (2025-01-15,파스타,cho)
# (2025-01-16,간짜장,cho)
# (2025-01-17,스파게티,cho)
# (2025-01-20,버섯 비프 카레,cho)
# (2025-01-21,스파게티,cho)
# (2025-01-22,설렁탕,cho)
# (2025-01-23,치킨마요덮밥,cho)
# (2025-01-24,등심돈까스,cho)
# (2025-02-03,치즈라면, 김밥,cho)
# (2025-01-07,닭개장(특) , 꽈배기,hyun)
# (2025-01-08,주먹밥,hyun)
# (2025-01-09,얼큰 순대국밥,hyun)
# (2025-01-10,불닭로제찜닭,hyun)
# (2025-01-13,한솥,hyun)
# (2025-01-14,순대국밥,hyun)
# (2025-01-15,까르보나라 파스타,hyun)
# (2025-01-16,간짜장 곱빼기,hyun)
# (2025-01-17,참치김밥,라볶이,hyun)
# ...
